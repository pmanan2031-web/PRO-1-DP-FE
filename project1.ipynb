# %%
import pandas as pd
import numpy as np
import sqlite3
import requests
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("customer2.csv")
print(df)
# Out:
#     CustomerID          Name   Age  Gender   Income  Purchases Churn
# 0         1001    Amit Patel   NaN    Male  35000.0        5.0    No
# 1         1002    Priya Shah  30.0  Female      NaN        8.0    No
# 2         1003           NaN  45.0    Male  70000.0       12.0   Yes
# 3         1004    Neha Verma  28.0  Female  48000.0        7.0    No
# 4         1005   Karan Singh  35.0    Male      NaN       10.0    No
# 5         1006  Pooja Sharma   NaN  Female  75000.0       15.0   Yes
# 6         1007   Rohan Desai  23.0    Male  32000.0        NaN    No
# 7         1008  Anjali Joshi  31.0  Female  52000.0        9.0    No
# 8         1009           NaN  50.0    Male  85000.0       18.0   Yes
# 9         1010   Sneha Patel  27.0  Female  46000.0        6.0   NaN
# 10        1011    Arjun Nair   NaN    Male  68000.0       13.0   Yes
# 11        1012   Kavya Reddy  29.0  Female  54000.0        NaN    No
# 12        1013  Manish Gupta  33.0    Male      NaN       11.0    No
# ...

# %%
print(df.head())
# Out:
#    CustomerID         Name   Age  Gender   Income  Purchases Churn
# 0        1001   Amit Patel   NaN    Male  35000.0        5.0    No
# 1        1002   Priya Shah  30.0  Female      NaN        8.0    No
# 2        1003          NaN  45.0    Male  70000.0       12.0   Yes
# 3        1004   Neha Verma  28.0  Female  48000.0        7.0    No
# 4        1005  Karan Singh  35.0    Male      NaN       10.0    No

# %%
print("info",df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  20 non-null     int64
#  1   Name        17 non-null     object
#  2   Age         16 non-null     float64
#  3   Gender      20 non-null     object
#  4   Income      15 non-null     float64
#  5   Purchases   18 non-null     float64
#  6   Churn       18 non-null     object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.2+ KB
# info None

# %%
print("describe",df.describe())
# Out:
# describe        CustomerID        Age        Income  Purchases
# count    20.00000  16.000000     15.000000  18.000000
# mean   1010.50000  33.687500  57733.333333  10.333333
# std       5.91608   8.388236  17396.496637   4.115966
# min    1001.00000  23.000000  32000.000000   4.000000
# 25%    1005.75000  27.750000  44500.000000   7.250000
# 50%    1010.50000  31.500000  54000.000000  10.500000
# 75%    1015.25000  38.000000  71500.000000  12.750000
# max    1020.00000  50.000000  85000.000000  18.000000

# %%
json_df = pd.read_json("customer2.json")

print(json_df.head())
# Out:
#    CustomerID        Name  Age  Gender  Income  Purchases Churn
# 0        1001  Amit Patel   25    Male   35000          5    No
# 1        1002  Priya Shah   30  Female   50000          8    No

# %%
conn = sqlite3.connect("customer.db")

query = "SELECT * FROM Customers"

sql_df = pd.read_sql(query, conn)

print(sql_df.head())

conn.close()
# Out:
#    CustomerID  Age  Gender  Income  Purchases  PurchaseFrequency  \
# 0        1001   56  Female   46976         37                 18
# 1        1002   46  Female   69262         32                 15
# 2        1003   32    Male   48776          9                  2
# 3        1004   60    Male   55080         41                 10
# 4        1005   25    Male   91842         35                  2
#
#    MembershipDuration  Churn
# 0                  49      1
# 1                  28      1
# 2                  32      0
# 3                  27      0
# 4                  20      0

# %%
url = "https://jsonplaceholder.typicode.com/users"

response = requests.get(url)

api_data = response.json()

api_df = pd.DataFrame(api_data)

print(api_df.head())
# Out:
#    id              name   username                      email  \
# 0   1     Leanne Graham       Bret          Sincere@april.biz
# 1   2      Ervin Howell  Antonette          Shanna@melissa.tv
# 2   3  Clementine Bauch   Samantha         Nathan@yesenia.net
# 3   4  Patricia Lebsack   Karianne  Julianne.OConner@kory.org
# 4   5  Chelsey Dietrich     Kamren   Lucio_Hettinger@annie.ca
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
#
#          website                                            company
# ...

# %%
print("head",df.head())
# Out:
# head    CustomerID         Name   Age  Gender   Income  Purchases Churn
# 0        1001   Amit Patel   NaN    Male  35000.0        5.0    No
# 1        1002   Priya Shah  30.0  Female      NaN        8.0    No
# 2        1003          NaN  45.0    Male  70000.0       12.0   Yes
# 3        1004   Neha Verma  28.0  Female  48000.0        7.0    No
# 4        1005  Karan Singh  35.0    Male      NaN       10.0    No

# %%
print("null values",df.isnull().sum())
# Out:
# null values CustomerID    0
# Name          3
# Age           4
# Gender        0
# Income        5
# Purchases     2
# Churn         2
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
# Numerical
num_cols=df.select_dtypes(include=np.number).columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# Categorical
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode().iloc[0])

print(df.isnull().sum())
# Out:
# CustomerID    0
# Name          0
# Age           0
# Gender        0
# Income        0
# Purchases     0
# Churn         0
# dtype: int64

# %%
sns.histplot(df["Age"],kde=True,shrink=0.4)
plt.show()

# %%
sns.histplot(df["Income"],kde=True,shrink=0.4)
plt.show()

# %%
sns.histplot(df["Purchases"],kde=True,shrink=0.4)
plt.show()

# %%
sns.boxplot(x="Gender", y="Purchases", data=df)
plt.title("Gender vs Purchases")
plt.show()

# %%
sns.boxplot(x="Churn", y="Income", data=df)
plt.title("Gender vs Purchases")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.heatmap(
    df.select_dtypes(include=np.number).corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df)

plt.show()

# %%
from ydata_profiling import ProfileReport

# Generate profiling report
profile = ProfileReport(df, title="Titanic Dataset Report", explorative=True)

# Display in Jupyter Notebook
profile.to_notebook_iframe()

# Save to HTML file
profile.to_file("titanic_report.html")
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-06-02 10:39:44.450663&quot; name=date&gt;&lt;title&gt;Titanic Dataset Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
